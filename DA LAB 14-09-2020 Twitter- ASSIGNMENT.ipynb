# %% [markdown]
# #  Anirudh Singh Chauhan

# %%
import tweepy
from tweepy import OAuthHandler
import numpy as np
import pandas as pd

# %%
'''
consumer_key = 'TgHNMa7WZE7Cxi1JbkAMQ'
consumer_secret = 'SHy9mBMBPNj3Y17et9BF4g5XeqS4y3vkeW24PttDcY' 
access_token = '908720407682875393-DkzbECIW8Z6Alp3axpLgv3njJ1zcjAU' 
access_secret = 'ZMcWhoSNDYFUWT8aItpYrIg95CGJGYD2zfjerxhqfsstu' 
'''
consumer_key = 'SOZ0M5WM2HkJk1dDvxaDciZMQ'
consumer_secret = 'Vy9VYfpKXFqgJlNrXxqW9bLSVB5ZVNtpjCOByqJmed4VoBGw6X'
access_token = '283418461-l6nuPhoVOG046YyVbGqKWX2Of8krIQx5FXSMAUKj'
access_token_secret = 'mmdBqmMCPQrNTANSyoMa1d76CqEImVqsvDgvadGPKos06'

# %%
from tweepy.auth import OAuthHandler

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
results = []
i=0
for tweet in tweepy.Cursor(api.search, q='NEET', lang= 'en').items():
    if (not tweet.retweeted) and ('RT @' not in tweet.text): 
        results.append(tweet) 
        id = tweet.id 
        i=i+1 
        if i==50: 
            break 
print (len(results))
# Out:
# 50

# %%
'''
Tweet related features : created_at, retweet_count, source
User related features : user_description, user_follower_count, user_friends_count, user_location, user_verified, user_url 
Extra Feature: Length of tweet
'''
# Out:
# '\nTweet related features : created_at, retweet_count, source\nUser related features : user_description, user_follower_count, user_friends_count, user_location, user_verified, user_url \nExtra Feature: Length of tweet\n'

# %%
def process_results(results):
    id_list = [tweet.id for tweet in results]
    data_set = pd.DataFrame(id_list, columns=["id"])
    
    data_set["created_at"] = [tweet.created_at for tweet in results]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in results]
    data_set["source"] = [tweet.source for tweet in results]
    
    data_set["user_id"] = [tweet.author.id for tweet in results]
    data_set["user_name"]=[tweet.author.name for tweet in results]
    data_set["user_description"] = [tweet.author.description for tweet in results]
    data_set["user_follower_count"] = [tweet.author.followers_count for tweet in results]
    data_set["user_friends_count"] = [tweet.author.friends_count for tweet in results]
    data_set["user_location"] = [tweet.author.location for tweet in results]
    data_set["user_verified"] = [tweet.author.verified for tweet in results]
    data_set["user_url"] = [tweet.author.url for tweet in results]
    
    data_set["length_of_tweet"] = [len(tweet.text) for tweet in results]
    
    return data_set

# %%
data_set=process_results(results)

# %%
data_set
# Out:
#                      id          created_at  retweet_count  \
# 0   1305869236628226050 2020-09-15 14:01:02              0
# 1   1305869114536230914 2020-09-15 14:00:33              0
# 2   1305869023394123778 2020-09-15 14:00:11              0
# 3   1305868911896940545 2020-09-15 13:59:45              0
# 4   1305868872935972866 2020-09-15 13:59:35              0
# 5   1305868858205630464 2020-09-15 13:59:32              0
# 6   1305868835656998914 2020-09-15 13:59:26              0
# 7   1305868807005777924 2020-09-15 13:59:20              0
# 8   1305868777146535939 2020-09-15 13:59:12              0
# 9   1305868736625344512 2020-09-15 13:59:03              0
# 10  1305868524003434504 2020-09-15 13:58:12              1
# 11  1305868485290061829 2020-09-15 13:58:03              0
# 12  1305868460749094912 2020-09-15 13:57:57              0
# 13  1305868440629055490 2020-09-15 13:57:52              0
# 14  1305868247082958850 2020-09-15 13:57:06              0
# ...

# %%
data_set.to_csv("Neet_tweet_data.csv", index=False, encoding='utf-8')
